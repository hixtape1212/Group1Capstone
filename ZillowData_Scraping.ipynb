# %% [markdown]
#    # Group 1 Data Exploration and Scraping

# %% [markdown]
# ### Our group has found a potential dataset but will need some amount of web scraping to make it complete and usable

# %%
# Taking a look at the desired dataset missing one attribute
# The data in this set is 2 years old w/ one price
# From kaggle put together for a data science college project
import pandas as pd
import requests

# %%
df = pd.read_csv('data/austinHousingData.csv')
df.head()
# Out:
#          zpid          city          streetAddress  zipcode  \
# 0   111373431  pflugerville   14424 Lake Victor Dr    78660
# 1   120900430  pflugerville     1104 Strickling Dr    78660
# 2  2084491383  pflugerville    1408 Fort Dessau Rd    78660
# 3   120901374  pflugerville     1025 Strickling Dr    78660
# 4    60134862  pflugerville  15005 Donna Jane Loop    78660
#
#                                          description   latitude  longitude  \
# 0  14424 Lake Victor Dr, Pflugerville, TX 78660 i...  30.430632 -97.663078
# 1  Absolutely GORGEOUS 4 Bedroom home with 2 full...  30.432672 -97.661697
# 2  Under construction - estimated completion in A...  30.409748 -97.639771
# 3  Absolutely darling one story home in charming ...  30.432112 -97.661659
# 4  Brimming with appeal & warm livability! Sleek ...  30.437368 -97.656860
#
#    propertyTaxRate  garageSpaces  hasAssociation  ...  numOfMiddleSchools  \
# 0             1.98             2            True  ...                   1
# ...

# %%
df.describe()
# Out:
#                zpid       zipcode      latitude     longitude  \
# count  1.517100e+04  15171.000000  15171.000000  15171.000000
# mean   1.044193e+08  78735.932964     30.291596    -97.778532
# std    3.179426e+08     18.893475      0.096973      0.084715
# min    2.858495e+07  78617.000000     30.085030    -98.022057
# 25%    2.941115e+07  78727.000000     30.203313    -97.838009
# 50%    2.949441e+07  78739.000000     30.284416    -97.769539
# 75%    7.033762e+07  78749.000000     30.366585    -97.717903
# max    2.146313e+09  78759.000000     30.517323    -97.569504
#
#        propertyTaxRate  garageSpaces  parkingSpaces     yearBuilt  \
# count     15171.000000  15171.000000   15171.000000  15171.000000
# mean          1.994085      1.229187       1.224507   1988.554743
# std           0.053102      1.352117       1.352732     21.579458
# min           1.980000      0.000000       0.000000   1905.000000
# 25%           1.980000      0.000000       0.000000   1974.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15171 entries, 0 to 15170
# Data columns (total 47 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   zpid                        15171 non-null  int64
#  1   city                        15171 non-null  object
#  2   streetAddress               15171 non-null  object
#  3   zipcode                     15171 non-null  int64
#  4   description                 15171 non-null  object
#  5   latitude                    15171 non-null  float64
#  6   longitude                   15171 non-null  float64
#  7   propertyTaxRate             15171 non-null  float64
#  8   garageSpaces                15171 non-null  int64
#  9   hasAssociation              15171 non-null  bool
#  10  hasCooling                  15171 non-null  bool
#  11  hasGarage                   15171 non-null  bool
#  12  hasHeating                  15171 non-null  bool
# ...

# %% [markdown]
# ## Initial Thoughts
# The dataset is very clean, with no non-null and most relevant features in int or float format. Now we need to use some form of datascaping to gather current home prices based on the web-addresses. Another option is to use a large dataset that we've found with current housing prices and link those to the columns in the other dataframe. We will try that below.

# %%
df_cp = pd.read_csv('data/realtor-data.csv')
df_cp.head()
# Out:
#      status     price  bed  bath  acre_lot  \
# 0  for_sale  105000.0  3.0   2.0      0.12
# 1  for_sale   80000.0  4.0   2.0      0.08
# 2  for_sale   67000.0  2.0   1.0      0.15
# 3  for_sale  145000.0  4.0   2.0      0.10
# 4  for_sale   65000.0  6.0   2.0      0.05
#
#                                         full_address  \
# 0  Sector Yahuecas Titulo # V84, Adjuntas, PR, 00601
# 1            Km 78 9 Carr # 135, Adjuntas, PR, 00601
# 2            556G 556-G 16 St, Juana Diaz, PR, 00795
# 3  R5 Comunidad El Paraso Calle De Oro R-5 Ponce,...
# 4                    14 Navarro, Mayaguez, PR, 00680
#
#                                           street        city        state  \
# 0                   Sector Yahuecas Titulo # V84    Adjuntas  Puerto Rico
# 1                             Km 78 9 Carr # 135    Adjuntas  Puerto Rico
# 2                               556G 556-G 16 St  Juana Diaz  Puerto Rico
# 3  R5 Comunidad El Paraso Calle De Oro R-5 Ponce       Ponce  Puerto Rico
# ...

# %%
df_cp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 613159 entries, 0 to 613158
# Data columns (total 12 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   status        613159 non-null  object
#  1   price         613159 non-null  float64
#  2   bed           507459 non-null  float64
#  3   bath          513691 non-null  float64
#  4   acre_lot      474193 non-null  float64
#  5   full_address  613159 non-null  object
#  6   street        612227 non-null  object
#  7   city          613095 non-null  object
#  8   state         613159 non-null  object
#  9   zip_code      612958 non-null  float64
#  10  house_size    440048 non-null  float64
#  11  sold_date     264934 non-null  object
# dtypes: float64(6), object(6)
# memory usage: 56.1+ MB

# %%
df_cp.state.value_counts()
# Out:
# Massachusetts     175248
# New Jersey         92047
# Connecticut        89776
# New York           63287
# New Hampshire      51394
# Vermont            46460
# Maine              36650
# Rhode Island       29596
# Puerto Rico        24679
# Virgin Islands      2573
# Pennsylvania        1032
# Delaware             296
# Georgia               50
# South Carolina        25
# Virginia              20
# Tennessee             20
# Wyoming                3
# West Virginia          3
# Name: state, dtype: int64

# %%
# Pull in only homes in TX
TX_df_cp = df_cp[(df_cp['state'] == 'Texas')]
TX_df_cp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   status        0 non-null      object
#  1   price         0 non-null      float64
#  2   bed           0 non-null      float64
#  3   bath          0 non-null      float64
#  4   acre_lot      0 non-null      float64
#  5   full_address  0 non-null      object
#  6   street        0 non-null      object
#  7   city          0 non-null      object
#  8   state         0 non-null      object
#  9   zip_code      0 non-null      float64
#  10  house_size    0 non-null      float64
#  11  sold_date     0 non-null      object
# dtypes: float64(6), object(6)
# memory usage: 0.0+ bytes

# %% [markdown]
# Discovered that the dataset has no homes in Texas which is really great:)
