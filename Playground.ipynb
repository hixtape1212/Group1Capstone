# %%
# Taking an initial look at the data that was pulled and seeing where we can minipulate

# %%
import pandas as pd
import numpy as np

# %%
z_df = pd.read_csv('data/ZHVI_7-6.csv')
z_df.head()
# Out:
#    RegionID  SizeRank       RegionName RegionType StateName     2000-01-31  \
# 0    102001         0    United States    country       NaN  115935.315864
# 1    394913         1     New York, NY        msa        NY  186046.302192
# 2    753899         2  Los Angeles, CA        msa        CA  227934.131438
# 3    394463         3      Chicago, IL        msa        IL  144602.588994
# 4    394514         4       Dallas, TX        msa        TX  131691.578887
#
#       2000-02-29     2000-03-31     2000-04-30     2000-05-31  ...  \
# 0  116139.215245  116391.926673  116933.820095  117557.349159  ...
# 1  186838.051955  187635.907417  189251.805042  190921.921031  ...
# 2  228777.236621  229903.721020  232164.561730  234644.880021  ...
# 3  144739.692986  144997.704274  145640.559139  146412.480383  ...
# 4  131757.478505  131831.950940  132018.256645  132256.269885  ...
#
#       2022-08-31     2022-09-30     2022-10-31     2022-11-30     2022-12-31  \
# ...

# %%
z_df.describe()
# Out:
#             RegionID    SizeRank     2000-01-31     2000-02-29     2000-03-31  \
# count     895.000000  895.000000     431.000000     432.000000     433.000000
# mean   412099.672626  461.751955  102356.494301  102539.902797  102701.881629
# std     78377.355083  268.710532   47834.912329   47948.800059   48123.293872
# min    102001.000000    0.000000   26981.490627   26945.260353   26903.736346
# 25%    394546.000000  230.500000   68753.202441   68948.872847   69190.223168
# 50%    394795.000000  460.000000   91138.306863   91147.744933   91065.982413
# 75%    395044.500000  689.500000  121805.392884  121944.468824  122262.522401
# max    753929.000000  939.000000  383129.300848  385015.142026  387891.092049
#
#           2000-04-30     2000-05-31     2000-06-30     2000-07-31  \
# count     435.000000     437.000000     438.000000     439.000000
# mean   103321.831658  104076.424932  104608.445133  105330.311208
# std     48757.639734   49409.531021   50016.353247   50696.503645
# ...

# %%
z_df.shape
# Out:
# (895, 286)

# %%
z_df.columns
# Out:
# Index(['RegionID', 'SizeRank', 'RegionName', 'RegionType', 'StateName',
#        '2000-01-31', '2000-02-29', '2000-03-31', '2000-04-30', '2000-05-31',
#        ...
#        '2022-08-31', '2022-09-30', '2022-10-31', '2022-11-30', '2022-12-31',
#        '2023-01-31', '2023-02-28', '2023-03-31', '2023-04-30', '2023-05-31'],
#       dtype='object', length=286)

# %%
z_df.RegionName.describe()
# Out:
# count              895
# unique             895
# top       Marietta, OH
# freq                 1
# Name: RegionName, dtype: object

# %%
import matplotlib.pyplot as plt
plt.hist(
    z_df.SizeRank
)
# Out:
# (array([91., 93., 90., 91., 92., 90., 92., 91., 82., 83.]),
#  array([  0. ,  93.9, 187.8, 281.7, 375.6, 469.5, 563.4, 657.3, 751.2,
#         845.1, 939. ]),
#  <BarContainer object of 10 artists>)

# %%
z_df.SizeRank.describe()
# Out:
# count    895.000000
# mean     461.751955
# std      268.710532
# min        0.000000
# 25%      230.500000
# 50%      460.000000
# 75%      689.500000
# max      939.000000
# Name: SizeRank, dtype: float64
